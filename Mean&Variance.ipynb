# %% [markdown]
# <a href="https://colab.research.google.com/github/dileepkumarreddy-3/MLA0406/blob/main/Mean%26Variance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Sample data (heights in cm)
heights = np.array([160, 162, 165, 170, 168,
                    172, 169, 171, 167, 166])

# Maximum Likelihood Estimate of Mean
mean_mle = np.mean(heights)

# Maximum Likelihood Estimate of Variance
variance_mle = np.mean((heights - mean_mle) ** 2)

print("MLE Mean =", mean_mle)
print("MLE Variance =", variance_mle)
# Out:
# MLE Mean = 167.0
# MLE Variance = 13.4
